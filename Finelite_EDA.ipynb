# %% [markdown]
# # 📊 Credit Card Bank Customer Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_excel('../DataSets/Credir_Card_Bank.xlsx')

# %%
df
# Out:
#      Customer_ID  Age  Gender Employment_Type       Occupation  \
# 0      CUST00001   41  Female        Salaried  Sales Executive
# 1      CUST00002   23    Male   Self-Employed   Business Owner
# 2      CUST00003   45  Female        Salaried         Designer
# 3      CUST00004   39    Male        Salaried           Doctor
# 4      CUST00005   58    Male   Self-Employed         Designer
# ...          ...  ...     ...             ...              ...
# 4995   CUST04996   48    Male        Salaried           Doctor
# 4996   CUST04997   59  Female   Self-Employed       Accountant
# 4997   CUST04998   26  Female        Salaried           Doctor
# 4998   CUST04999   42    Male        Salaried          Manager
# 4999   CUST05000   55  Female   Self-Employed   Business Owner
#
#       Monthly_Income  Annual_Income  Credit_Score  Years_With_Bank  \
# 0             140273        1683276           811                4
# 1             209521        2514252           837               12
# ...

# %%
df.head()
# Out:
#   Customer_ID  Age  Gender Employment_Type       Occupation  Monthly_Income  \
# 0   CUST00001   41  Female        Salaried  Sales Executive          140273
# 1   CUST00002   23    Male   Self-Employed   Business Owner          209521
# 2   CUST00003   45  Female        Salaried         Designer           47682
# 3   CUST00004   39    Male        Salaried           Doctor          214966
# 4   CUST00005   58    Male   Self-Employed         Designer           30051
#
#    Annual_Income  Credit_Score  Years_With_Bank  Existing_Credit_Cards  ...  \
# 0        1683276           811                4                      4  ...
# 1        2514252           837               12                      2  ...
# 2         572184           679                2                      6  ...
# 3        2579592           660                5                      0  ...
# 4         360612           589               18                      0  ...
#
# ...

# %%
df.tail()
# Out:
#      Customer_ID  Age  Gender Employment_Type      Occupation  Monthly_Income  \
# 4995   CUST04996   48    Male        Salaried          Doctor           55078
# 4996   CUST04997   59  Female   Self-Employed      Accountant          107040
# 4997   CUST04998   26  Female        Salaried          Doctor          168754
# 4998   CUST04999   42    Male        Salaried         Manager          197110
# 4999   CUST05000   55  Female   Self-Employed  Business Owner          126915
#
#       Annual_Income  Credit_Score  Years_With_Bank  Existing_Credit_Cards  \
# 4995         660936           824               12                      1
# 4996        1284480           840                0                      1
# 4997        2025048           632               19                      0
# 4998        2365320           734                9                      2
# 4999        1522980           709               12                      5
#
# ...

# %%
df.shape
# Out:
# (5000, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               5000 non-null   object
#  1   Age                       5000 non-null   int64
#  2   Gender                    5000 non-null   object
#  3   Employment_Type           5000 non-null   object
#  4   Occupation                5000 non-null   object
#  5   Monthly_Income            5000 non-null   int64
#  6   Annual_Income             5000 non-null   int64
#  7   Credit_Score              5000 non-null   int64
#  8   Years_With_Bank           5000 non-null   int64
#  9   Existing_Credit_Cards     5000 non-null   int64
#  10  Existing_Credit_Limit     5000 non-null   int64
#  11  Loan_Count                5000 non-null   int64
#  12  EMI_Per_Month             5000 non-null   int64
#  13  Debt_To_Income_Ratio      5000 non-null   float64
# ...

# %%
df.describe()
# Out:
#                Age  Monthly_Income  Annual_Income  Credit_Score  \
# count  5000.000000     5000.000000   5.000000e+03   5000.000000
# mean     40.536400   137142.403200   1.645709e+06    701.922400
# std      11.524289    65319.533295   7.838344e+05     86.428479
# min      21.000000    25000.000000   3.000000e+05    550.000000
# 25%      30.000000    80798.250000   9.695790e+05    628.000000
# 50%      41.000000   138066.000000   1.656792e+06    701.500000
# 75%      50.000000   193029.250000   2.316351e+06    777.000000
# max      60.000000   249908.000000   2.998896e+06    850.000000
#
#        Years_With_Bank  Existing_Credit_Cards  Existing_Credit_Limit  \
# count      5000.000000            5000.000000             5000.00000
# mean         10.119600               3.020400           504801.14360
# std           6.012797               2.005789           291438.83248
# min           0.000000               0.000000               56.00000
# ...

# %%
df.dtypes
# Out:
# Customer_ID                  object
# Age                           int64
# Gender                       object
# Employment_Type              object
# Occupation                   object
# Monthly_Income                int64
# Annual_Income                 int64
# Credit_Score                  int64
# Years_With_Bank               int64
# Existing_Credit_Cards         int64
# Existing_Credit_Limit         int64
# Loan_Count                    int64
# EMI_Per_Month                 int64
# Debt_To_Income_Ratio        float64
# Savings_Balance               int64
# Investment_Value              int64
# Avg_Monthly_Transactions      int64
# Avg_Monthly_Spending        float64
# Credit_Utilization            int64
# Credit_History_Years          int64
# Missed_Payments               int64
# Late_Payment_Count            int64
# Number_of_Defaults            int64
# Residential_Status           object
# PAN_Verified                 object
# KYC_Status                   object
# ...

# %% [markdown]
# #  📋 DataSet Overview

# %%
df.Age.value_counts()
# Out:
# Age
# 55    143
# 39    142
# 41    140
# 27    137
# 53    136
# 48    136
# 57    136
# 34    135
# 59    135
# 21    135
# 26    134
# 36    133
# 45    133
# 28    133
# 23    132
# 56    130
# 30    130
# 29    128
# 37    128
# 44    128
# 46    125
# 49    125
# 43    124
# 47    124
# 24    123
# 50    123
# 58    120
# 40    119
# 25    119
# 32    119
# 52    118
# 35    116
# 33    115
# 31    113
# 54    113
# 42    108
# 51    107
# 60    107
# 38    105
# 22     93
# Name: count, dtype: int64

# %%
df.Occupation.value_counts()
# Out:
# Occupation
# Sales Executive      664
# Software Engineer    655
# Designer             651
# Accountant           642
# Doctor               617
# Manager              599
# Teacher              598
# Business Owner       574
# Name: count, dtype: int64

# %%
df.Annual_Income.describe()
# Out:
# count    5.000000e+03
# mean     1.645709e+06
# std      7.838344e+05
# min      3.000000e+05
# 25%      9.695790e+05
# 50%      1.656792e+06
# 75%      2.316351e+06
# max      2.998896e+06
# Name: Annual_Income, dtype: float64

# %%
df.KYC_Status.value_counts()
# Out:
# KYC_Status
# Complete    5000
# Name: count, dtype: int64

# %%
df.Employment_Type.value_counts()
# Out:
# Employment_Type
# Self-Employed    2516
# Salaried         2484
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# Female    2522
# Male      2478
# Name: count, dtype: int64

# %%
df.Monthly_Income.value_counts()
# Out:
# Monthly_Income
# 110838    2
# 170508    2
# 208947    2
# 177715    2
# 144474    2
#          ..
# 216899    1
# 140059    1
# 196850    1
# 172575    1
# 126915    1
# Name: count, Length: 4953, dtype: int64

# %%
df.Residential_Status.value_counts()
# Out:
# Residential_Status
# Own     2515
# Rent    2485
# Name: count, dtype: int64

# %%
df.Late_Payment_Count.value_counts()
# Out:
# Late_Payment_Count
# 1    593
# 6    592
# 2    580
# 0    556
# 3    549
# 5    539
# 4    538
# 8    534
# 7    519
# Name: count, dtype: int64

# %%
df.Missed_Payments.value_counts()
# Out:
# Missed_Payments
# 1    867
# 2    849
# 0    848
# 3    846
# 5    811
# 4    779
# Name: count, dtype: int64

# %%
df.Credit_Score.value_counts()
# Out:
# Credit_Score
# 554    29
# 678    28
# 800    26
# 824    26
# 798    25
#        ..
# 688     8
# 573     8
# 595     8
# 583     8
# 556     7
# Name: count, Length: 301, dtype: int64

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Age', 'Gender', 'Employment_Type', 'Occupation',
#        'Monthly_Income', 'Annual_Income', 'Credit_Score', 'Years_With_Bank',
#        'Existing_Credit_Cards', 'Existing_Credit_Limit', 'Loan_Count',
#        'EMI_Per_Month', 'Debt_To_Income_Ratio', 'Savings_Balance',
#        'Investment_Value', 'Avg_Monthly_Transactions', 'Avg_Monthly_Spending',
#        'Credit_Utilization', 'Credit_History_Years', 'Missed_Payments',
#        'Late_Payment_Count', 'Number_of_Defaults', 'Residential_Status',
#        'PAN_Verified', 'KYC_Status', 'Fraud_Flag', 'Credit_Limit'],
#       dtype='object')

# %%
df.Loan_Count.value_counts()
# Out:
# Loan_Count
# 3    1037
# 4    1003
# 1     999
# 2     988
# 0     973
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Customer_ID                 0
# Age                         0
# Gender                      0
# Employment_Type             0
# Occupation                  0
# Monthly_Income              0
# Annual_Income               0
# Credit_Score                0
# Years_With_Bank             0
# Existing_Credit_Cards       0
# Existing_Credit_Limit       0
# Loan_Count                  0
# EMI_Per_Month               0
# Debt_To_Income_Ratio        0
# Savings_Balance             0
# Investment_Value            0
# Avg_Monthly_Transactions    0
# Avg_Monthly_Spending        0
# Credit_Utilization          0
# Credit_History_Years        0
# Missed_Payments             0
# Late_Payment_Count          0
# Number_of_Defaults          0
# Residential_Status          0
# PAN_Verified                0
# KYC_Status                  0
# Fraud_Flag                  0
# Credit_Limit                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 👥 Distribution Analysis of Customer Financial & Demographic Features

# %%
sb.histplot(df["Age"],bins=20,kde=True,color='teal')
plt.show()

# %%
sb.histplot(df.Monthly_Income,bins=20,kde=True,color='plum')
plt.show()

# %%
sb.histplot(df.Annual_Income,bins=20,kde=True,color='red')
plt.show()

# %%
sb.histplot(df["Savings_Balance"], bins=15, kde=True, color="brown")
plt.show()

# %%
sb.histplot(df["Credit_History_Years"], bins=15, kde=True, color="green")
plt.show()

# %%
plt.figure(figsize=(14,10))

#Age Distribution Analysis
plt.subplot(2,3,1)
sb.histplot(df["Age"],bins=20,kde=True,color='teal')
plt.title("Age Distribution")

#Annual Income Distribution
plt.subplot(2,3,2)
sb.histplot(df["Annual_Income"],bins=20,kde=True,color='red')
plt.title("Annual Income")

#Savings Balance Distribution
plt.subplot(2,3,3)
sb.histplot(df["Savings_Balance"], bins=15, kde=True, color="brown")
plt.title("Saving Balance")

#Credit History Analysis (Years)
plt.subplot(2,3,4)
sb.histplot(df["Credit_History_Years"], bins=15, kde=True, color="green")
plt.title("History of Credit Cards")

#Existing Credit Cards Analysis
plt.subplot(2,3,5)
sb.histplot(df["Existing_Credit_Cards"], bins=15, kde=True, color="orange")
plt.title("Existing_Credit_Cards")

#Investment Value Distribution
plt.subplot(2,3,6)
sb.histplot(df["Investment_Value"], bins=15, kde=True, color="plum")
plt.title("Investment_Value")

plt.suptitle("Distribution Analysis of Customer Financial & Demographic Features",fontsize=16, fontweight='bold', y=1.00)
plt.show()

# %% [markdown]
# # 📈 Distribution Analysis

# %%
plt.figure(figsize=(16,10))

plt.subplot(2,2,1)
sb.boxplot(df.Age,color='lightgreen')
plt.title("Age Distribution")

plt.subplot(2,2,2)
sb.boxplot(df.Monthly_Income,color='yellowgreen')
plt.title("Monthly Income Distribution")

plt.subplot(2,2,3)
sb.boxplot(df.Annual_Income,color='turquoise')
plt.title("Annual Income Distribution")

plt.subplot(2,2,4)
sb.boxplot(df.Credit_Limit,color='olive')
plt.title("Credit Limit Distribution")

plt.suptitle("Distribution Analysis",fontsize=16, fontweight="bold")
plt.show()

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  Monthly_Income  Annual_Income  \
# Age                       1.000000        0.000586       0.000586
# Monthly_Income            0.000586        1.000000       1.000000
# Annual_Income             0.000586        1.000000       1.000000
# Credit_Score             -0.004417       -0.014696      -0.014696
# Years_With_Bank           0.001938       -0.022105      -0.022105
# Existing_Credit_Cards     0.033044       -0.009906      -0.009906
# Existing_Credit_Limit     0.015468        0.012751       0.012751
# Loan_Count                0.013240       -0.021474      -0.021474
# EMI_Per_Month             0.018521        0.008250       0.008250
# Debt_To_Income_Ratio     -0.001949        0.001379       0.001379
# Savings_Balance          -0.005467       -0.005543      -0.005543
# Investment_Value          0.004425       -0.022537      -0.022537
# Avg_Monthly_Transactions -0.001134        0.006890       0.006890
# ...

# %% [markdown]
# # 📊 Customer Financial & Credit Analysis

# %%
sb.scatterplot(x=df.Savings_Balance,y=df.Investment_Value,color='teal')
plt.title("Saving  VS  Investment")
plt.show()

# %%
sb.scatterplot(x=df.Monthly_Income,y=df.Credit_Limit, color="khaki")
plt.title("Monthly Income vs Credit Limit")
plt.show()

# %%
sb.scatterplot(x=df.Debt_To_Income_Ratio, y=df.Credit_Score, color="royalblue")
plt.title("Debt Ratio vs Credit Score")
plt.show()

# %%
sb.scatterplot(x=df.Existing_Credit_Cards, y=df.Credit_Score, color="orchid")
plt.title("Credit Card vs Credit Score")
plt.show()

# %%
sb.scatterplot(data=df, x=df.Annual_Income, y=df.Credit_Limit, color="green")
plt.title("Annual Income vs Credit Limit")
plt.show()

# %%
sb.scatterplot(x=df.Monthly_Income, y=df.Savings_Balance, color="peru")
plt.title("Monthly Income vs Savings Balance")
plt.show()

# %%
fig = plt.figure(figsize=(20,16))

# 1. Saving  VS  Investment 
fig.add_subplot(331)
sb.scatterplot(x=df.Savings_Balance,y=df.Investment_Value,color='teal')
plt.title("Saving  VS  Investment")

# 2. Credit Score vs Credit Limit
fig.add_subplot(332)
sb.scatterplot(x=df.Monthly_Income, y=df.Credit_Limit, color="khaki")
plt.title("Monthly Income VS Credit Limit")

# 3. Debt Ratio vs Credit Score
fig.add_subplot(333)
sb.scatterplot(x=df.Debt_To_Income_Ratio, y=df.Credit_Score, color="royalblue")
plt.title("Debt Ratio VS Credit Score")

# 4. Annual Income vs Credit Limit
fig.add_subplot(335)
sb.scatterplot(x=df.Annual_Income, y=df.Credit_Limit, color="green")
plt.title("Annual Income VS Credit Limit")

# 5. Credit Card vs Credit Score
fig.add_subplot(334)
sb.scatterplot(x=df.Existing_Credit_Cards, y=df.Credit_Score, color="orchid")
plt.title("Existing Credit Cards VS Credit Score")

# 6. Years with Bank vs Credit History Years
fig.add_subplot(336)
sb.scatterplot(x=df.Monthly_Income, y=df.Savings_Balance, color="peru")
plt.title("Monthly Income VS Savings Balance")

#7. Credit History Years VS Credit Score
fig.add_subplot(337)
sb.scatterplot(x=df.Credit_History_Years,y=df.Credit_Score,color="red")
plt.title("Credit History Years VS Credit Score")

# 8. Monthly Income VS Annual Income
fig.add_subplot(338)
sb.scatterplot(x=df.Monthly_Income,y=df.Annual_Income,hue=df.Gender)
plt.title("Monthly Income VS Annual Income")


plt.suptitle("Customer Financial & Credit Analysis",fontsize=16, fontweight="bold")
plt.show()

# %% [markdown]
# # Distribution of Customer Demographic and Credit Features

# %%
sb.countplot(x=df.Gender,color="skyblue")
plt.title("Gender Distribution")
plt.show()

# %%
sb.countplot(x=df.Employment_Type,color='teal')
plt.show()

# %%
sb.countplot(x=df.Residential_Status,color='gold')
plt.show()

# %%
sb.countplot(x=df.Fraud_Flag,color="red")
plt.show()

# %%
sb.countplot(x=df.Loan_Count, color="orange")
plt.title("Loan Count Distribution")
plt.show()

# %%
fig = plt.figure(figsize=(20,15))

# 1. Gender Distribution
fig.add_subplot(331)
sb.countplot(x=df.Gender,color="skyblue")
plt.title("Gender Distribution")

# 2. Employment Type Distribution
fig.add_subplot(332)
sb.countplot(x=df.Employment_Type,color='teal')
plt.title("Employment Type")

# 3. Residential Status Distribution 
fig.add_subplot(333)
sb.countplot(x=df.Residential_Status,color='gold')
plt.title("Residental_Status")

# 4. Fraud Flag Distribution
fig.add_subplot(334)
sb.countplot(x=df.Fraud_Flag,color="red")
plt.title("Fraud Flag")

# 5. Loan Count Distribution
fig.add_subplot(335)
sb.countplot(x=df.Loan_Count, color="orange")
plt.title("Loan Count Distribution")

# 6. Existing Credit Cards Distribution
fig.add_subplot(336)
sb.countplot(x=df.Existing_Credit_Cards, color="green")
plt.title("Existing Credit Cards")

# 7. Occupation Distribution
fig.add_subplot(337)
sb.countplot(x=df.Occupation,palette='autumn')
plt.xticks(rotation=90)
plt.title("Occupation")

plt.suptitle("Distribution of Customer Demographic and Credit Features",fontsize=18,fontweight="bold")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\2871518332.py:35: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.countplot(x=df.Occupation,palette='autumn')

# %%
sb.pairplot(
    df[['Age',
        'Monthly_Income',
        'Credit_Score',
        'Credit_Limit',
        'Credit_Utilization',
        'Debt_To_Income_Ratio']]
)

plt.show()

# %% [markdown]
# # 🧩 Data Aggregation & Analysis

# %%
df.groupby('Gender')['Monthly_Income'].mean()
# Out:
# Gender
# Female    138430.335448
# Male      135831.602098
# Name: Monthly_Income, dtype: float64

# %%
df.groupby('Occupation')['Monthly_Income'].mean()
# Out:
# Occupation
# Accountant           137895.791277
# Business Owner       136197.412892
# Designer             131921.410138
# Doctor               136954.035656
# Manager              138051.160267
# Sales Executive      140512.097892
# Software Engineer    136063.871756
# Teacher              139648.178930
# Name: Monthly_Income, dtype: float64

# %%
df.groupby('Residential_Status')['Credit_Limit'].sum()
# Out:
# Residential_Status
# Own     3553363006
# Rent    3522476160
# Name: Credit_Limit, dtype: int64

# %%
pd.pivot_table(df,values="Credit_Limit",index="Occupation",columns="Gender",aggfunc="sum")
# Out:
# Gender                Female       Male
# Occupation
# Accountant         425463116  483575758
# Business Owner     396738655  414510526
# Designer           475679672  429305095
# Doctor             481783753  385556637
# Manager            441464138  411513520
# Sales Executive    494685174  457401243
# Software Engineer  448956420  476772534
# Teacher            414773371  437659554

# %%
df.nunique()
# Out:
# Customer_ID                 5000
# Age                           40
# Gender                         2
# Employment_Type                2
# Occupation                     8
# Monthly_Income              4953
# Annual_Income               4953
# Credit_Score                 301
# Years_With_Bank               21
# Existing_Credit_Cards          7
# Existing_Credit_Limit       4985
# Loan_Count                     5
# EMI_Per_Month               4795
# Debt_To_Income_Ratio          56
# Savings_Balance             4992
# Investment_Value            4995
# Avg_Monthly_Transactions     241
# Avg_Monthly_Spending        4918
# Credit_Utilization            91
# Credit_History_Years          26
# Missed_Payments                6
# Late_Payment_Count             9
# Number_of_Defaults             2
# Residential_Status             2
# PAN_Verified                   1
# KYC_Status                     1
# Fraud_Flag                     2
# Credit_Limit                4987
# dtype: int64

# %%
pd.pivot_table(df,values='Credit_Score',index='Gender',columns='Employment_Type',aggfunc='mean')
# Out:
# Employment_Type    Salaried  Self-Employed
# Gender
# Female           700.583134     704.154941
# Male             700.086390     702.811351

# %%
df.Annual_Income.nlargest(10)
# Out:
# 185     2998896
# 2319    2997828
# 3404    2996952
# 1078    2996856
# 3526    2996652
# 2881    2996220
# 667     2996076
# 2827    2995656
# 3126    2995644
# 356     2995428
# Name: Annual_Income, dtype: int64

# %%
df.Credit_Score.nsmallest(10)
# Out:
# 119     550
# 665     550
# 787     550
# 976     550
# 1038    550
# 1365    550
# 1872    550
# 2595    550
# 2897    550
# 3624    550
# Name: Credit_Score, dtype: int64

# %%
df.skew(numeric_only=True)
# Out:
# Age                        -0.003523
# Monthly_Income             -0.006908
# Annual_Income              -0.006908
# Credit_Score               -0.014779
# Years_With_Bank            -0.037844
# Existing_Credit_Cards      -0.009247
# Existing_Credit_Limit      -0.011014
# Loan_Count                 -0.021875
# EMI_Per_Month              -0.026974
# Debt_To_Income_Ratio        0.019037
# Savings_Balance            -0.006901
# Investment_Value            0.018816
# Avg_Monthly_Transactions   -0.030300
# Avg_Monthly_Spending        0.871869
# Credit_Utilization         -0.005938
# Credit_History_Years        0.010016
# Missed_Payments             0.044190
# Late_Payment_Count          0.030140
# Number_of_Defaults          3.570683
# Credit_Limit               -0.012653
# dtype: float64

# %%
plt.figure(figsize=(7,5))

sb.boxplot(x=df['Number_of_Defaults'])
plt.title("Distribution of Number of Defaults")
plt.xlabel("Number of Defaults")
plt.show()

# %%
df.groupby('Occupation')['Monthly_Income'].mean()
# Out:
# Occupation
# Accountant           137895.791277
# Business Owner       136197.412892
# Designer             131921.410138
# Doctor               136954.035656
# Manager              138051.160267
# Sales Executive      140512.097892
# Software Engineer    136063.871756
# Teacher              139648.178930
# Name: Monthly_Income, dtype: float64

# %%
df.groupby('Occupation')['Credit_Score'].mean()
# Out:
# Occupation
# Accountant           701.976636
# Business Owner       699.982578
# Designer             701.743472
# Doctor               699.705024
# Manager              703.749583
# Sales Executive      701.813253
# Software Engineer    702.862595
# Teacher              703.469900
# Name: Credit_Score, dtype: float64

# %%
df.Monthly_Income.nlargest(10)
# Out:
# 185     249908
# 2319    249819
# 3404    249746
# 1078    249738
# 3526    249721
# 2881    249685
# 667     249673
# 2827    249638
# 3126    249637
# 356     249619
# Name: Monthly_Income, dtype: int64

# %%
df.Monthly_Income.nsmallest(10)
# Out:
# 396     25000
# 3616    25005
# 2652    25022
# 1431    25043
# 1192    25081
# 2024    25116
# 3018    25132
# 4927    25132
# 509     25138
# 3825    25209
# Name: Monthly_Income, dtype: int64

# %%
pd.crosstab(df["Gender"],df["Employment_Type"])
# Out:
# Employment_Type  Salaried  Self-Employed
# Gender
# Female               1257           1265
# Male                 1227           1251

# %%
df.Credit_Score.nlargest(10)
# Out:
# 40      850
# 104     850
# 628     850
# 900     850
# 936     850
# 1076    850
# 1266    850
# 1311    850
# 1375    850
# 1568    850
# Name: Credit_Score, dtype: int64

# %%
df.groupby("Loan_Count")["Credit_Score"].mean()
# Out:
# Loan_Count
# 0    704.066804
# 1    700.295295
# 2    697.296559
# 3    706.811958
# 4    700.964108
# Name: Credit_Score, dtype: float64

# %%
df.groupby('Late_Payment_Count')['Credit_Score'].mean()
# Out:
# Late_Payment_Count
# 0    701.307554
# 1    703.846543
# 2    703.513793
# 3    697.329690
# 4    698.624535
# 5    705.309833
# 6    702.451014
# 7    696.292871
# 8    708.207865
# Name: Credit_Score, dtype: float64

# %%
df.groupby('Fraud_Flag')['Credit_Score'].mean()
# Out:
# Fraud_Flag
# No     701.931396
# Yes    700.909091
# Name: Credit_Score, dtype: float64

# %% [markdown]
# ##### The average credit score of fraud-flagged and non-fraud-flagged customers is very similar, suggesting that credit score alone may not be sufficient to distinguish potentially fraudulent customers.

# %%
df.groupby('PAN_Verified')['Credit_Score'].mean()
# Out:
# PAN_Verified
# Yes    701.9224
# Name: Credit_Score, dtype: float64

# %%
df.groupby('KYC_Status')['Credit_Score'].mean()
# Out:
# KYC_Status
# Complete    701.9224
# Name: Credit_Score, dtype: float64

# %% [markdown]
# ##### PAN verification and KYC status show no variation in the dataset.

# %%
df.groupby('Residential_Status')['Credit_Score'].mean()
# Out:
# Residential_Status
# Own     700.764215
# Rent    703.094567
# Name: Credit_Score, dtype: float64

# %% [markdown]
# #### Average credit scores are broadly similar across residential statuses, with renters showing a slightly higher average score

# %% [markdown]
# # 💳 Credit & Customer Analysis

# %%
sb.barplot(x=df.Gender,y=df.Credit_Score,palette="coolwarm")
plt.title("Gender vs Credit Score")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\3922951731.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Gender,y=df.Credit_Score,palette="coolwarm")

# %%
sb.barplot(x=df.Loan_Count,y=df.Credit_Score,palette="Accent")
plt.title("Loan Count VS Credit Score")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\402844255.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Loan_Count,y=df.Credit_Score,palette="Accent")

# %%
sb.barplot(x=df.Gender,y=df.Monthly_Income, palette="Set1")
plt.title("Gender VS Monthly Income")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\1364661335.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Gender,y=df.Monthly_Income, palette="Set1")

# %%
sb.barplot(x=df.Gender,y=df.Annual_Income,palette="Set2")
plt.title("Gender VS Annual Income")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\972634890.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Gender,y=df.Annual_Income,palette="Set2")

# %%
sb.barplot(x=df.Occupation,y=df.Credit_Limit,palette="Set2")
plt.xticks(rotation=90)
plt.title("Occupation VS Credit Limit")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\2858014343.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Occupation,y=df.Credit_Limit,palette="Set2")

# %%
sb.barplot(x=df.Employment_Type,y=df.Monthly_Income,palette="Set3")
plt.title("Employment Type VS Monthly_Income")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\1052727876.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Employment_Type,y=df.Monthly_Income,palette="Set3")

# %%
plt.figure(figsize=(18,12))

# 1. Average Credit Score by Gender
plt.subplot(2,3,1)
sb.barplot(x=df.Gender,y=df.Credit_Score,palette="coolwarm")
plt.title("Gender vs Credit Score")

# 2. Average Credit Score by Loan Count
plt.subplot(2,3,2)
sb.barplot(x=df.Loan_Count,y=df.Credit_Score,palette="Accent")
plt.title("Loan Count VS Credit Score")

# 3. Average Monthly Income by Gender
plt.subplot(2,3,3)
sb.barplot(x=df.Gender,y=df.Monthly_Income, palette="Set1")
plt.title("Gender VS Monthly Income")

# 4. Average Annual Income by Gender
plt.subplot(2,3,4)
sb.barplot(x=df.Gender,y=df.Annual_Income,palette="Set2")
plt.title("Gender VS Annual Income")

# 5. Average Credit Limit by Occupation
plt.subplot(2,3,5)
sb.barplot(x=df.Occupation,y=df.Credit_Limit,palette="Set2")
plt.xticks(rotation=90)
plt.title("Occupation VS Credit Limit")

# 6. Average Monthly Income by Employment Type
plt.subplot(2,3,6)
sb.barplot(x=df.Employment_Type,y=df.Monthly_Income,palette="Set3")
plt.title("Employment Type VS Monthly_Income")

plt.suptitle("Customer Insights",fontsize=18,fontweight="bold")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\1165512304.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Gender,y=df.Credit_Score,palette="coolwarm")
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\1165512304.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Loan_Count,y=df.Credit_Score,palette="Accent")
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\1165512304.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Gender,y=df.Monthly_Income, palette="Set1")
# ...

# %%
sb.lineplot(x=df.Years_With_Bank,y=df.Credit_Score,color="darkviolet")
plt.show()

# %%
sb.barplot(x=df.Existing_Credit_Cards,y=df.Credit_Score,palette="spring")
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\2114983577.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.barplot(x=df.Existing_Credit_Cards,y=df.Credit_Score,palette="spring")

# %%
plt.figure(figsize=(18,12))

plt.subplot(2,2,1)
sb.boxplot(x=df.Fraud_Flag,y=df.Credit_Score,palette="autumn")
plt.title("Fraud and Credit Score")


plt.subplot(2,2,2)
sb.boxplot(x=df.Employment_Type,y=df.Credit_Score,palette="summer")
plt.title("Employment Type and Credit Score")
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\3487882479.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df.Fraud_Flag,y=df.Credit_Score,palette="autumn")
# C:\Users\hp\AppData\Local\Temp\ipykernel_13252\3487882479.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.boxplot(x=df.Employment_Type,y=df.Credit_Score,palette="summer")
# Text(0.5, 1.0, 'Employmebt Type and Credit Score')

# %%
plt.figure(figsize=(18,12))


plt.subplot(2,2,1)
sb.regplot(x=df.Monthly_Income,y=df.Credit_Score,color="slategray")
plt.title("Monthly Income and Credit Score")

plt.subplot(2,2,2)
sb.regplot(x=df.Debt_To_Income_Ratio,y=df.Credit_Score,color="tan")
plt.title("Debt Ratio And Credit Score")

plt.show()
